# %%
import datetime
from zoneinfo import ZoneInfo
# from pathlib import Path
import pathlib

import numpy as np
import subprocess
import os
import getpass


import morph_analyses as m


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mouse = m.mouse_metadata.rare_mice[0]
metadata = m.mouse_metadata.rare_sessions[mouse]
session = metadata['test_sessions'][0]

# %%
session
# Out:
# {'date_str': '19_02_2019',
#  'scene': 'TwoTower_foraging',
#  'session': 2,
#  'scan': 2,
#  'day': 8}

# %%
nwb_maker = m.create_nwb.SessNWBConverter(mouse, metadata, session, training_session=False)

# %%
nwb_maker.build_file()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 nwb_maker.build_file()
#
# File ~/repos/PlittGiocomo_CA1Morph_2019/src/morph_analyses/create_nwb.py:367, in SessNWBConverter.build_file(self)
#     366 def build_file(self):
# --> 367     self.init_nwb_file()
#     368     self.add_vr_data_aligned()
#     369     self.init_2p_data()
#
# File ~/repos/PlittGiocomo_CA1Morph_2019/src/morph_analyses/create_nwb.py:111, in SessNWBConverter.init_nwb_file(self)
#      94     description = f"Testing session. Morph task. " + self.sub_notes
#      96 self.nwb_file = NWBFile(
#      97     session_description = "Preprocessed 2P and VR Data",
#      98     session_start_time = datetime.datetime.now().astimezone(),
#    (...)    106     keywords=["two photon", "hipppocampus", "CA1", "remapping"]
#     107 )
#     109 self.nwb_file.subject = Subject(
#     110     subject_id = self.metadata.get('alias'),
# --> 111     age = self.session.get('datetime') - self.metadata.get('date_of_birth'),
#     112     description = self.sub_description,
#     113     species = 'Mus musculus',
#     114     sex = self.metadata.get('sex'),
#     115     genotype = self.session.get('genotype'),
#     116 )
#     118 self.behavior_module = self.nwb_file.create_processing_module('behavior', 'VR behavioral timeseries')
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'datetime.datetime'
