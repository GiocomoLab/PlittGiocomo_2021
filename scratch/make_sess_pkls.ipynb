# %%
import os
import numpy as np
import pathlib
import pickletools
import morph_analyses as m

# %load_ext autoreload
# %autoreload 2

# %%
twop_basedir = pathlib.Path('/mnt/BigDisk/2P_scratch/TwoTower')
vr_basedir = pathlib.Path('/mnt/BigDisk/morph_vr_data/')

# %%
def make_f_dict(mouse, date, sess, scan):
    f = {
        'mouse': mouse,
        'scan_file': twop_basedir / mouse / date / 'TwoTower_foraging' / f"TwoTower_foraging_{sess:03d}_{scan:03d}.sbx",
        'scanheader_file': twop_basedir / mouse / date / 'TwoTower_foraging' / f"TwoTower_foraging_{sess:03d}_{scan:03d}.mat",
        'vr_filename': vr_basedir / mouse / date / f"TwoTower_foraging_{sess}.sqlite",
        's2p_path': twop_basedir / mouse / date / 'TwoTower_foraging' / f"TwoTower_foraging_{sess:03d}_{scan:03d}" / "suite2p",
        'prompt_for_keys': False,
        'VR_only': False,
        'scanner': 'NLW',
    }
    f['scan_file'] = str(f['scan_file'])
    f['scanheader_file'] = str(f['scanheader_file'])
    f['vr_filename'] = str(f['vr_filename'])
    f['s2p_path'] = str(f['s2p_path'])
    return f

# %%
for mouse, metadata in m.mouse_metadata.rare_sessions.items():
    print(f"Processing {mouse}...")
    for sess_deets in metadata['test_sessions']+metadata['training_sessions']:
        print(sess_deets)
        outfile = f"/home/mplitt/morph_sess_pkls/{mouse}/{sess_deets['date_str']}/TwoTower_foraging_{sess_deets['session']}.pkl"
        # if os.path.exists(outfile):
        #     print(f"File {outfile} already exists, skipping...")
        #     continue

        f = make_f_dict(mouse, sess_deets['date_str'], sess_deets['session'], sess_deets['scan'])

        sess = m.sess.CA1MorphSession(**f)
        sess.load_scan_info()
        sess.align_VR_to_2P()
        sess.get_trial_info()
        sess.load_suite2p_data()
        sess.gen_standard_ts_tmats()
        sess.place_cells_calc(nperms=100)

        sess.save(outfile)
# Out:
# Processing 4139265.3...
# {'date_str': '19_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 2}
# Fixing teleports
# frame rate 15.4609375
# (115307,) ttl times,(35085,) ca2+ frame times
# last time: VR 2269.2827185447195, ca2+ 2269.202627589692
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# /mnt/BigDisk/2P_scratch/TwoTower/4139265.3/19_02_2019/TwoTower_foraging/TwoTower_foraging_002_002/suite2p
# perm 0
# {'date_str': '21_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# Fixing teleports
# frame rate 15.4609375
# (109003,) ttl times,(33140,) ca2+ frame times
# last time: VR 2143.504926730672, ca2+ 2143.401718039414
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /mnt/BigDisk/2P_scratch/TwoTower/4139265.3/21_02_2019/TwoTower_foraging/TwoTower_foraging_002_003/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# perm 0
# {'date_str': '22_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# Fixing teleports
# frame rate 15.4609375
# (126969,) ttl times,(38209,) ca2+ frame times
# last time: VR 2471.3467660434562, ca2+ 2471.2602324406266
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /mnt/BigDisk/2P_scratch/TwoTower/4139265.3/22_02_2019/TwoTower_foraging/TwoTower_foraging_002_003/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# perm 0
# {'date_str': '23_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 11}
# Fixing teleports
# frame rate 15.4609375
# (110218,) ttl times,(33547,) ca2+ frame times
# last time: VR 2169.8150581101568, ca2+ 2169.726124305205
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /mnt/BigDisk/2P_scratch/TwoTower/4139265.3/23_02_2019/TwoTower_foraging/TwoTower_foraging_002_011/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# perm 0
# {'date_str': '24_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 4}
# Fixing teleports
# frame rate 15.4609375
# (105022,) ttl times,(32038,) ca2+ frame times
# last time: VR 2072.2541687721073, ca2+ 2072.125315816069
# /mnt/BigDisk/2P_scratch/TwoTower/4139265.3/24_02_2019/TwoTower_foraging/TwoTower_foraging_002_004/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# perm 0
# {'date_str': '10_02_2019', 'scene': 'TwoTower_foraging', 'session': 1, 'scan': 1, 'notes': 'blocked 0 and 1 morph trials'}
# Fixing teleports
# frame rate 15.4609375
# (62980,) ttl times,(18730,) ca2+ frame times
# last time: VR 1211.4748610409297, ca2+ 1211.3754421424962
# /mnt/BigDisk/2P_scratch/TwoTower/4139265.3/10_02_2019/TwoTower_foraging/TwoTower_foraging_001_001/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# perm 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 18
#      16 sess.load_suite2p_data()
#      17 sess.gen_standard_ts_tmats()
# ---> 18 sess.place_cells_calc(nperms=100)
#      20 sess.save(outfile)
#
# File ~/repos/PlittGiocomo_CA1Morph_2019/src/morph_analyses/sess.py:59, in CA1MorphSession.place_cells_calc(self, **pc_kwargs)
#      57 def place_cells_calc(self,  **pc_kwargs):
# ---> 59     masks, SI, pvals = pc.place_cells_calc(self.timeseries['spks_norm'].T,
#      60                                         self.vr_data['pos'],
#      61                                         self.trial_info,
#      62                                         self.trial_start_inds,
#      63                                         self.teleport_inds,
#      64                                         morphlist=np.unique(self.trial_info['morphs']).tolist(),
#      65                                         **pc_kwargs)
#      66     d = self.place_cell_info
#      67     d['masks'] = masks
#
# File ~/repos/PlittGiocomo_CA1Morph_2019/src/morph_analyses/PlaceCellAnalysis.py:233, in place_cells_calc(C, position, trial_info, tstart_inds, teleport_inds, pthr, speed, win_trial_perm, morphlist, bootstrap, nperms)
#     231 if perm%100 == 0:
#     232     print('perm',perm)
# --> 233 C_trial_mat, occ_trial_mat, _,__ = u.make_pos_bin_trial_matrices(C,position,tstart_inds,teleport_inds,speed = speed,perm=True)
#     234 _SI_perm =  spatinfo_per_morph(C_trial_mat,occ_trial_mat)
#     235 for m in _SI_perm.keys():
#
# File ~/repos/PlittGiocomo_CA1Morph_2019/src/morph_analyses/utilities.py:269, in make_pos_bin_trial_matrices(arr, pos, tstart_inds, tstop_inds, bin_size, max_pos, speed, speed_thr, perm, mat_only)
#     267 if np.where((pos_t>edge1) & (pos_t<=edge2))[0].shape[0]>0:
#     268     trial_mat[trial,b] = np.nanmean(arr_t[(pos_t>edge1) & (pos_t<=edge2),:],axis=0)
# --> 269     occ_mat[trial,b] = np.where((pos_t>edge1) & (pos_t<=edge2))[0].shape[0]
#     270 else:
#     271     pass
#
# File ~/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/_core/multiarray.py:403, in where(condition, x, y)
#     311     """
#     312     inner(a, b, /)
#     313
#    (...)    398
#     399     """
#     400     return (a, b)
# --> 403 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     404 def where(condition, x=None, y=None, /):
#     405     """
#     406     where(condition, [x, y], /)
#     407
#    (...)    474            [ 0,  3, -1]])
#     475     """
#     476     return (condition, x, y)
#
# KeyboardInterrupt:

# %%
mouse = '4343703.1'
sess_deets = m.mouse_metadata.rare_sessions[mouse]['training_sessions'][-1]
outfile = f"/home/mplitt/morph_sess_pkls/{mouse}/{sess_deets['date_str']}/TwoTower_foraging_{sess_deets['session']}.pkl"

f = make_f_dict(mouse, sess_deets['date_str'], sess_deets['session'], sess_deets['scan'])

sess = m.sess.CA1MorphSession(**f)
sess.load_scan_info()
sess.align_VR_to_2P()
# Out:
# Fixing teleports
# frame rate 15.4609375
# (74091,) ttl times,(27059,) ca2+ frame times
# last time: VR 1750.1960586154623, ca2+ 1750.0879231935323
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:260: UserWarning: Number of teleports and trial starts don't match
#   warnings.warn("Number of teleports and trial starts don't match")
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:262: UserWarning: One more teleport and than trial start, Assuming the first trial start got clipped
#   warnings.warn(("One more teleport and than trial start, Assuming the first trial start got clipped"))
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:263: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['tstart'].iloc[0]=1
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0

# %%
for (trial, (start, end)) in enumerate(zip(sess.trial_start_inds, np.append(sess.trial_start_inds, sess.teleport_inds))): 
    print(f"Trial {trial}: start idx {start}, end idx {end}")
    print(sess.vr_data.iloc[start:end]['morph'])
# Out:
# Trial 0: start idx 463, end idx 463
# Series([], Name: morph, dtype: object)
# Trial 1: start idx 747, end idx 747
# Series([], Name: morph, dtype: object)
# Trial 2: start idx 1055, end idx 1055
# Series([], Name: morph, dtype: object)
# Trial 3: start idx 1322, end idx 1322
# Series([], Name: morph, dtype: object)
# Trial 4: start idx 1588, end idx 1588
# Series([], Name: morph, dtype: object)
# Trial 5: start idx 1801, end idx 1801
# Series([], Name: morph, dtype: object)
# Trial 6: start idx 2070, end idx 2070
# Series([], Name: morph, dtype: object)
# Trial 7: start idx 2351, end idx 2351
# Series([], Name: morph, dtype: object)
# Trial 8: start idx 2602, end idx 2602
# Series([], Name: morph, dtype: object)
# Trial 9: start idx 2844, end idx 2844
# Series([], Name: morph, dtype: object)
# Trial 10: start idx 3127, end idx 3127
# Series([], Name: morph, dtype: object)
# Trial 11: start idx 3392, end idx 3392
# Series([], Name: morph, dtype: object)
# Trial 12: start idx 3654, end idx 3654
# Series([], Name: morph, dtype: object)
# Trial 13: start idx 3908, end idx 3908
# Series([], Name: morph, dtype: object)
# Trial 14: start idx 4173, end idx 4173
# Series([], Name: morph, dtype: object)
# Trial 15: start idx 4413, end idx 4413
# Series([], Name: morph, dtype: object)
# Trial 16: start idx 4669, end idx 4669
# Series([], Name: morph, dtype: object)
# Trial 17: start idx 4935, end idx 4935
# Series([], Name: morph, dtype: object)
# Trial 18: start idx 5161, end idx 5161
# Series([], Name: morph, dtype: object)
# Trial 19: start idx 5430, end idx 5430
# Series([], Name: morph, dtype: object)
# Trial 20: start idx 5652, end idx 5652
# Series([], Name: morph, dtype: object)
# Trial 21: start idx 5861, end idx 5861
# Series([], Name: morph, dtype: object)
# Trial 22: start idx 6183, end idx 6183
# Series([], Name: morph, dtype: object)
# Trial 23: start idx 6476, end idx 6476
# Series([], Name: morph, dtype: object)
# Trial 24: start idx 6776, end idx 6776
# Series([], Name: morph, dtype: object)
# Trial 25: start idx 7038, end idx 7038
# Series([], Name: morph, dtype: object)
# Trial 26: start idx 7460, end idx 7460
# Series([], Name: morph, dtype: object)
# Trial 27: start idx 8011, end idx 8011
# Series([], Name: morph, dtype: object)
# Trial 28: start idx 8227, end idx 8227
# Series([], Name: morph, dtype: object)
# Trial 29: start idx 8461, end idx 8461
# Series([], Name: morph, dtype: object)
# Trial 30: start idx 8683, end idx 8683
# Series([], Name: morph, dtype: object)
# Trial 31: start idx 8903, end idx 8903
# Series([], Name: morph, dtype: object)
# Trial 32: start idx 9167, end idx 9167
# Series([], Name: morph, dtype: object)
# Trial 33: start idx 9460, end idx 9460
# Series([], Name: morph, dtype: object)
# Trial 34: start idx 9704, end idx 9704
# Series([], Name: morph, dtype: object)
# Trial 35: start idx 10001, end idx 10001
# Series([], Name: morph, dtype: object)
# Trial 36: start idx 10242, end idx 10242
# Series([], Name: morph, dtype: object)
# Trial 37: start idx 10508, end idx 10508
# Series([], Name: morph, dtype: object)
# Trial 38: start idx 10768, end idx 10768
# Series([], Name: morph, dtype: object)
# Trial 39: start idx 11049, end idx 11049
# Series([], Name: morph, dtype: object)
# Trial 40: start idx 11300, end idx 11300
# Series([], Name: morph, dtype: object)
# Trial 41: start idx 11544, end idx 11544
# Series([], Name: morph, dtype: object)
# Trial 42: start idx 11771, end idx 11771
# Series([], Name: morph, dtype: object)
# Trial 43: start idx 12046, end idx 12046
# Series([], Name: morph, dtype: object)
# Trial 44: start idx 12282, end idx 12282
# Series([], Name: morph, dtype: object)
# Trial 45: start idx 12524, end idx 12524
# Series([], Name: morph, dtype: object)
# Trial 46: start idx 12855, end idx 12855
# Series([], Name: morph, dtype: object)
# Trial 47: start idx 13081, end idx 13081
# Series([], Name: morph, dtype: object)
# Trial 48: start idx 13332, end idx 13332
# Series([], Name: morph, dtype: object)
# Trial 49: start idx 13567, end idx 13567
# Series([], Name: morph, dtype: object)
# Trial 50: start idx 13824, end idx 13824
# Series([], Name: morph, dtype: object)
# Trial 51: start idx 14051, end idx 14051
# Series([], Name: morph, dtype: object)
# Trial 52: start idx 14306, end idx 14306
# Series([], Name: morph, dtype: object)
# Trial 53: start idx 14531, end idx 14531
# Series([], Name: morph, dtype: object)
# Trial 54: start idx 14777, end idx 14777
# Series([], Name: morph, dtype: object)
# Trial 55: start idx 15041, end idx 15041
# Series([], Name: morph, dtype: object)
# Trial 56: start idx 15501, end idx 15501
# Series([], Name: morph, dtype: object)
# Trial 57: start idx 15820, end idx 15820
# Series([], Name: morph, dtype: object)
# Trial 58: start idx 16040, end idx 16040
# Series([], Name: morph, dtype: object)
# Trial 59: start idx 16264, end idx 16264
# Series([], Name: morph, dtype: object)
# Trial 60: start idx 16513, end idx 16513
# Series([], Name: morph, dtype: object)
# Trial 61: start idx 16740, end idx 16740
# Series([], Name: morph, dtype: object)
# Trial 62: start idx 16996, end idx 16996
# Series([], Name: morph, dtype: object)
# Trial 63: start idx 17250, end idx 17250
# Series([], Name: morph, dtype: object)
# Trial 64: start idx 17530, end idx 17530
# Series([], Name: morph, dtype: object)
# Trial 65: start idx 17804, end idx 17804
# Series([], Name: morph, dtype: object)
# Trial 66: start idx 18080, end idx 18080
# Series([], Name: morph, dtype: object)
# Trial 67: start idx 18766, end idx 18766
# Series([], Name: morph, dtype: object)
# Trial 68: start idx 19157, end idx 19157
# Series([], Name: morph, dtype: object)
# Trial 69: start idx 19414, end idx 19414
# Series([], Name: morph, dtype: object)
# Trial 70: start idx 19687, end idx 19687
# Series([], Name: morph, dtype: object)
# Trial 71: start idx 19994, end idx 19994
# Series([], Name: morph, dtype: object)
# Trial 72: start idx 20278, end idx 20278
# Series([], Name: morph, dtype: object)
# Trial 73: start idx 20546, end idx 20546
# Series([], Name: morph, dtype: object)
# Trial 74: start idx 20824, end idx 20824
# Series([], Name: morph, dtype: object)
# Trial 75: start idx 21131, end idx 21131
# Series([], Name: morph, dtype: object)
# Trial 76: start idx 21361, end idx 21361
# Series([], Name: morph, dtype: object)
# Trial 77: start idx 21622, end idx 21622
# Series([], Name: morph, dtype: object)
# Trial 78: start idx 21844, end idx 21844
# Series([], Name: morph, dtype: object)
# Trial 79: start idx 22114, end idx 22114
# Series([], Name: morph, dtype: object)
# Trial 80: start idx 22365, end idx 22365
# Series([], Name: morph, dtype: object)
# Trial 81: start idx 22604, end idx 22604
# Series([], Name: morph, dtype: object)
# Trial 82: start idx 22815, end idx 22815
# Series([], Name: morph, dtype: object)
# Trial 83: start idx 23050, end idx 23050
# Series([], Name: morph, dtype: object)
# Trial 84: start idx 23296, end idx 23296
# Series([], Name: morph, dtype: object)
# Trial 85: start idx 23573, end idx 23573
# Series([], Name: morph, dtype: object)
# Trial 86: start idx 23821, end idx 23821
# Series([], Name: morph, dtype: object)
# Trial 87: start idx 24057, end idx 24057
# Series([], Name: morph, dtype: object)
# Trial 88: start idx 24323, end idx 24323
# Series([], Name: morph, dtype: object)
# Trial 89: start idx 24585, end idx 24585
# Series([], Name: morph, dtype: object)
# Trial 90: start idx 24847, end idx 24847
# Series([], Name: morph, dtype: object)
# Trial 91: start idx 25097, end idx 25097
# Series([], Name: morph, dtype: object)
# Trial 92: start idx 25334, end idx 25334
# Series([], Name: morph, dtype: object)
# Trial 93: start idx 25546, end idx 25546
# Series([], Name: morph, dtype: object)
# Trial 94: start idx 25858, end idx 25858
# Series([], Name: morph, dtype: object)
# Trial 95: start idx 26147, end idx 26147
# Series([], Name: morph, dtype: object)
# Trial 96: start idx 26396, end idx 26396
# Series([], Name: morph, dtype: object)
# Trial 97: start idx 26689, end idx 26689
# Series([], Name: morph, dtype: object)
# Trial 98: start idx 26906, end idx 26906
# Series([], Name: morph, dtype: object)

# %%
from matplotlib import pyplot as plt
plt.plot(sess.vr_data['pos'].iloc[:500])

# %%
sess.vr_data['morph'].unique()
# Out:
# array([-1.0, 0.5, 0.0, 0.25, 1.0, 0.75], dtype=object)

# %%
sess.trial_start_inds[:10]
# Out:
# Index([463, 747, 1055, 1322, 1588, 1801, 2070, 2351, 2602, 2844], dtype='int64')

# %%
for mouse, metadata in m.mouse_metadata.rare_sessions.items():
    print(f"Processing {mouse}...")
    for sess_deets in metadata['test_sessions']:
        print(sess_deets)
        outfile = f"/home/mplitt/morph_sess_pkls/{mouse}/{sess_deets['date_str']}/TwoTower_foraging_{sess_deets['session']}.pkl"
        if os.path.exists(outfile):
            sess = m.sess.CA1MorphSession.load(outfile)
# Out:
# Processing 4139265.3...
# {'date_str': '19_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 2}
# {'date_str': '21_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# {'date_str': '22_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# {'date_str': '23_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 11}
# {'date_str': '24_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 4}
# Processing 4139265.4...
# {'date_str': '17_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 8}
# {'date_str': '18_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# {'date_str': '19_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 2}
# {'date_str': '20_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# {'date_str': '21_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 6}
# {'date_str': '22_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 6}
# Processing 4139265.5...
# {'date_str': '19_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 5}
# {'date_str': '21_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 9}
# {'date_str': '22_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 10}
# {'date_str': '23_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 14}
# {'date_str': '24_02_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 7}
# Processing 4222168.1...
# {'date_str': '03_09_2019', 'scene': 'TwoTower_foraging', 'session': 4, 'scan': 9}
# {'date_str': '04_09_2019', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 4}
# {'date_str': '05_09_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 4}
# {'date_str': '06_09_2019', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 6}
# Processing 4343703.1...
# {'date_str': '22_03_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 2}
# Processing 4343706...
# {'date_str': '09_02_2020', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 7}
# {'date_str': '10_02_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 14}
# {'date_str': '11_02_2020', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 6}

# %%
for mouse, metadata in m.mouse_metadata.frequent_sessions.items():
    if mouse=='4343702.1':  # skip this mouse and run session manually
        continue
    print(f"Processing {mouse}...")
    for sess_deets in metadata['test_sessions']:
        print(sess_deets)
        outfile = f"/home/mplitt/morph_sess_pkls/{mouse}/{sess_deets['date_str']}/TwoTower_foraging_{sess_deets['session']}.pkl"
        if os.path.exists(outfile):
            print(f"File {outfile} already exists, skipping...")
            continue

        f = make_f_dict(mouse, sess_deets['date_str'], sess_deets['session'], sess_deets['scan'])

        sess = m.sess.CA1MorphSession(**f)
        sess.load_scan_info()
        sess.align_VR_to_2P()
        sess.load_suite2p_data()
        sess.gen_standard_ts_tmats()

        sess.save(outfile)
# Out:
# Processing 4222153.1...
# {'date_str': '15_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# Fixing teleports
# frame rate 15.4609375
# (118455,) ttl times,(36036,) ca2+ frame times
# last time: VR 2330.837165234967, ca2+ 2330.712481051036
# /mnt/BigDisk/2P_scratch/TwoTower/4222153.1/15_04_2019/TwoTower_foraging/TwoTower_foraging_002_003/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '16_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 6}
# Fixing teleports
# frame rate 15.4609375
# (111444,) ttl times,(33778,) ca2+ frame times
# last time: VR 2184.7892875189486, ca2+ 2184.6670035371403
# /mnt/BigDisk/2P_scratch/TwoTower/4222153.1/16_04_2019/TwoTower_foraging/TwoTower_foraging_002_006/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '17_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 17}
# Fixing teleports
# frame rate 15.4609375
# (118959,) ttl times,(35977,) ca2+ frame times
# last time: VR 2326.9874936836786, ca2+ 2326.8964123294595
# /mnt/BigDisk/2P_scratch/TwoTower/4222153.1/17_04_2019/TwoTower_foraging/TwoTower_foraging_002_017/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# Processing 4222153.2...
# {'date_str': '15_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 7}
# Fixing teleports
# frame rate 15.4609375
# (116195,) ttl times,(35248,) ca2+ frame times
# last time: VR 2279.8499242041435, ca2+ 2279.745325922183
# /mnt/BigDisk/2P_scratch/TwoTower/4222153.2/15_04_2019/TwoTower_foraging/TwoTower_foraging_002_007/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '16_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 9}
# Fixing teleports
# frame rate 15.4609375
# (121243,) ttl times,(33545,) ca2+ frame times
# last time: VR 2169.7007326932794, ca2+ 2169.5967660434567
# /mnt/BigDisk/2P_scratch/TwoTower/4222153.2/16_04_2019/TwoTower_foraging/TwoTower_foraging_002_009/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '17_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 2}
# Fixing teleports
# frame rate 15.4609375
# (129389,) ttl times,(38697,) ca2+ frame times
# last time: VR 2502.9178878221323, ca2+ 2502.823648307226
# /mnt/BigDisk/2P_scratch/TwoTower/4222153.2/17_04_2019/TwoTower_foraging/TwoTower_foraging_002_002/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '18_04_2019', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 3}
# Fixing teleports
# frame rate 15.4609375
# (121463,) ttl times,(37344,) ca2+ frame times
# last time: VR 2415.397675593734, ca2+ 2415.312784234462
# /mnt/BigDisk/2P_scratch/TwoTower/4222153.2/18_04_2019/TwoTower_foraging/TwoTower_foraging_003_003/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# Processing 4222153.3...
# {'date_str': '15_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 6}
# Fixing teleports
# frame rate 15.4609375
# (72892,) ttl times,(22769,) ca2+ frame times
# last time: VR 1472.7342091965638, ca2+ 1472.614451743305
# /mnt/BigDisk/2P_scratch/TwoTower/4222153.3/15_04_2019/TwoTower_foraging/TwoTower_foraging_002_006/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# Processing 4222174.1...
# {'date_str': '13_06_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 8}
# Fixing teleports
# frame rate 15.4609375
# (83238,) ttl times,(29526,) ca2+ frame times
# last time: VR 1909.7193026781204, ca2+ 1909.6513390601315
# /mnt/BigDisk/2P_scratch/TwoTower/4222174.1/13_06_2019/TwoTower_foraging/TwoTower_foraging_002_008/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '14_06_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 5}
# Fixing teleports
# frame rate 15.4609375
# (97310,) ttl times,(34560,) ca2+ frame times
# last time: VR 2235.358767054068, ca2+ 2235.246083880748
# /mnt/BigDisk/2P_scratch/TwoTower/4222174.1/14_06_2019/TwoTower_foraging/TwoTower_foraging_002_005/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '15_06_2019', 'scene': 'TwoTower_foraging', 'session': 3, 'scan': 8}
# Fixing teleports
# frame rate 15.4609375
# (86531,) ttl times,(30879,) ca2+ frame times
# last time: VR 1997.2426730672057, ca2+ 1997.1622031328955
# /mnt/BigDisk/2P_scratch/TwoTower/4222174.1/15_06_2019/TwoTower_foraging/TwoTower_foraging_003_008/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '17_06_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 7}
# Fixing teleports
# frame rate 15.4609375
# (80945,) ttl times,(28286,) ca2+ frame times
# last time: VR 1829.5855229914098, ca2+ 1829.4492167761498
# /mnt/BigDisk/2P_scratch/TwoTower/4222174.1/17_06_2019/TwoTower_foraging/TwoTower_foraging_002_007/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '18_06_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 21}
# Fixing teleports
# frame rate 15.4609375
# (91565,) ttl times,(31882,) ca2+ frame times
# last time: VR 2062.1555078322385, ca2+ 2062.035371399697
# /mnt/BigDisk/2P_scratch/TwoTower/4222174.1/18_06_2019/TwoTower_foraging/TwoTower_foraging_002_021/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# Processing 4222154.1...
# {'date_str': '15_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# Fixing teleports
# frame rate 15.4609375
# (106559,) ttl times,(32644,) ca2+ frame times
# last time: VR 2111.463239009601, ca2+ 2111.3208691258214
# /mnt/BigDisk/2P_scratch/TwoTower/4222154.1/15_04_2019/TwoTower_foraging/TwoTower_foraging_002_003/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '16_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 2}
# Fixing teleports
# frame rate 15.4609375
# (94524,) ttl times,(28890,) ca2+ frame times
# last time: VR 1868.6407276402224, ca2+ 1868.5154118241537
# /mnt/BigDisk/2P_scratch/TwoTower/4222154.1/16_04_2019/TwoTower_foraging/TwoTower_foraging_002_002/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '17_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 14}
# Fixing teleports
# frame rate 15.4609375
# (105737,) ttl times,(31805,) ca2+ frame times
# last time: VR 2057.194416371905, ca2+ 2057.0550783223853
# /mnt/BigDisk/2P_scratch/TwoTower/4222154.1/17_04_2019/TwoTower_foraging/TwoTower_foraging_002_014/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '18_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 2}
# Fixing teleports
# frame rate 15.4609375
# (110483,) ttl times,(33473,) ca2+ frame times
# last time: VR 2165.012379989894, ca2+ 2164.9398686205154
# /mnt/BigDisk/2P_scratch/TwoTower/4222154.1/18_04_2019/TwoTower_foraging/TwoTower_foraging_002_002/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# {'date_str': '19_04_2019', 'scene': 'TwoTower_foraging', 'session': 2, 'scan': 3}
# Fixing teleports
# frame rate 15.4609375
# (115107,) ttl times,(34639,) ca2+ frame times
# last time: VR 2240.455280444669, ca2+ 2240.355735219808
# /mnt/BigDisk/2P_scratch/TwoTower/4222154.1/19_04_2019/TwoTower_foraging/TwoTower_foraging_002_003/suite2p
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/numpy/lib/_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)

# %%
mouse = '4343702.1'
sess_deets = m.mouse_metadata.frequent_sessions[mouse]['test_sessions'][2]
# for sess_deets in metadata['test_sessions']:
#         print(sess_deets)
outfile = f"/home/mplitt/morph_sess_pkls/{mouse}/{sess_deets['date_str']}/TwoTower_foraging_{sess_deets['session']}.pkl"

   
f = make_f_dict(mouse, sess_deets['date_str'], sess_deets['session'], sess_deets['scan'])

sess = m.sess.CA1MorphSession(**f)
sess.load_scan_info()
sess.align_VR_to_2P()
# sess.load_suite2p_data()
# sess.gen_standard_ts_tmats()

# sess.save(outfile)
# Out:
# Fixing teleports
# frame rate 15.4609375
# (103786,) ttl times,(37732,) ca2+ frame times
# last time: VR 2440.5083375442146, ca2+ 2440.4082870136435
# /home/mplitt/repos/PlittGiocomo_CA1Morph_2019/.venv/lib/python3.11/site-packages/two_photon_utils/preprocessing.py:275: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   ca_df['speed'].iloc[0] = 0

# %%
sess.trial_matrices.keys()
# Out:
# dict_keys(['spks_norm', 'bin_edges', 'bin_centers', 'speed', 'licks'])

# %%
sess.vr_data.columns
# Out:
# Index(['time', 'morph', 'trialnum', 'pos', 'dz', 'lick', 'reward', 'tstart',
#        'teleport', 'rzone', 'toutzone', 'clickOn', 'blockWalls', 'towerJitter',
#        'wallJitter', 'bckgndJitter', 'scanning', 'manrewards', 'cmd', 'speed',
#        'lick rate'],
#       dtype='str')
